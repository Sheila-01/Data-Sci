# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("500000 Sales Records.csv")

# %%
data
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Total Revenue'], data['Total Cost'])
plt.xlabel('Total Revenue', fontsize = 15)
plt.ylabel('Total Cost', fontsize=15)
plt.xticks([0,1000000, 2000000, 3000000,4000000,5000000,6000000, 7000000], ['0','1M','2M','3M','4M','5M','6M','7M'])
plt.yticks([0,1000000, 2000000, 3000000,4000000,5000000], ['0','1M','2M','3M','4M','5M'])
plt.title('Sales Records', fontsize = 15)

plt.show()

# %%
plt.hist(data['Total Profit'])
plt.title('Sales Records Total Profits', fontsize= 15)
# plt.xlabel('Country')
plt.ylabel('Total Profit', fontsize = 15)
plt.show()

# %%
plt.hist(data['Units Sold'])
plt.title('Sales Records Units Sold', fontsize = 15)
# plt.xlabel('Country')
plt.ylabel('Units Sold', fontsize = 15)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(data['Country'], data['Total Revenue'])
# plt.xlabel('Country')
plt.ylabel('Total Revenue',fontsize = 15)
plt.xticks([0,1000000, 2000000, 3000000,4000000,5000000,6000000, 7000000], ['0','1M','2M','3M','4M','5M','6M','7M'])
plt.yticks([0,1000000, 2000000, 3000000,4000000,5000000], ['0','1M','2M','3M','4M','5M'])
plt.title('Sales Records Countries Revenue', fontsize = 15)

plt.show()

plt.hist(data['Unit Price'])
plt.title('Sales Records Unit Prices', fontsize= 15)
# plt.xlabel('Country')
plt.ylabel('Unit Price', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=[10,8])

plt.bar(bin_edges[:-1], hist, width = 0.5, color='#0504aa',alpha=0.7)
plt.xlim(min(bin_edges), max(bin_edges))
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Frequency',fontsize=15)
plt.title('Normal Distribution Histogram',fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-9b571f40394c> in <module>
#       3 plt.figure(figsize=[10,8])
#       4
# ----> 5 plt.bar(bin_edges[:-1], hist, width = 0.5, color='#0504aa',alpha=0.7)
#       6 plt.xlim(min(bin_edges), max(bin_edges))
#       7 plt.grid(axis='y', alpha=0.75)
#
# NameError: name 'bin_edges' is not defined

# %%
import matplotlib.pyplot as plt

plt.scatter(data['Unit Cost'], data['Total Cost'])
plt.xlabel('Unit Cost', fontsize=15)
plt.ylabel('Total Cost', fontsize=15)
plt.title('Unit Cost Against Total Cost', fontsize=15)

plt.show()

# %%
s = pd.Series(data['Country'])
s
# Out:
# 0             South Africa
# 1                  Morocco
# 2         Papua New Guinea
# 3                 Djibouti
# 4                 Slovakia
#                 ...
# 499995             Myanmar
# 499996         New Zealand
# 499997           Lithuania
# 499998            Malaysia
# 499999            Slovakia
# Name: Country, Length: 500000, dtype: object

# %%
s= pd.Series(data['Item Type'])
s
# Out:
# 0                  Fruits
# 1                 Clothes
# 2                    Meat
# 3                 Clothes
# 4               Beverages
#                ...
# 499995             Fruits
# 499996    Office Supplies
# 499997             Snacks
# 499998          Beverages
# 499999          Household
# Name: Item Type, Length: 500000, dtype: object

# %%
d= pd.Series(data['Item Type'])
d
# Out:
# 0                  Fruits
# 1                 Clothes
# 2                    Meat
# 3                 Clothes
# 4               Beverages
#                ...
# 499995             Fruits
# 499996    Office Supplies
# 499997             Snacks
# 499998          Beverages
# 499999          Household
# Name: Item Type, Length: 500000, dtype: object

# %%
s= pd.Series(data['Item Type'], data['Country'])
s
# Out:
# Country
# South Africa        NaN
# Morocco             NaN
# Papua New Guinea    NaN
# Djibouti            NaN
# Slovakia            NaN
#                    ...
# Myanmar             NaN
# New Zealand         NaN
# Lithuania           NaN
# Malaysia            NaN
# Slovakia            NaN
# Name: Item Type, Length: 500000, dtype: object

# %%
s= pd.Series(data['Item Type'], data['Country'])
s.index
# Out:
# Index(['South Africa', 'Morocco', 'Papua New Guinea', 'Djibouti', 'Slovakia',
#        'Sri Lanka', 'Seychelles ', 'Tanzania', 'Ghana', 'Tanzania',
#        ...
#        'Moldova ', 'Mauritania', 'Monaco', 'Tuvalu', 'Antigua and Barbuda ',
#        'Myanmar', 'New Zealand', 'Lithuania', 'Malaysia', 'Slovakia'],
#       dtype='object', name='Country', length=500000)

# %%
pd.Series(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-923bd34f7a2a> in <module>
# ----> 1 pd.Series(data)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
# --> 313                 data = SingleBlockManager(data, index, fastpath=True)
#     314
#     315         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1514
#    1515         if not isinstance(block, Block):
# -> 1516             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1517
#    1518         self.blocks = tuple([block])
#
# ...

# %%
s.array(data['Country'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-a0dd7776c9fe> in <module>
# ----> 1 s.array(data['Country'])
#
# TypeError: 'PandasArray' object is not callable

# %%
s.name
# Out:
# 'Item Type'

# %%
s2 = s.rename('Sales Records')
s2.name
# Out:
# 'Sales Records'

# %%
data.describe()
# Out:
#            Order ID     Units Sold     Unit Price      Unit Cost  \
# count  5.000000e+05  500000.000000  500000.000000  500000.000000
# mean   5.501319e+08    4999.136110     266.036748     187.528564
# std    2.599605e+08    2884.023907     216.937600     175.623982
# min    1.000029e+08       1.000000       9.330000       6.920000
# 25%    3.251814e+08    2502.000000      81.730000      56.670000
# 50%    5.491843e+08    4999.000000     154.060000      97.440000
# 75%    7.756291e+08    7497.000000     421.890000     263.330000
# max    9.999995e+08   10000.000000     668.270000     524.960000
#
#        Total Revenue    Total Cost  Total Profit
# count   5.000000e+05  5.000000e+05  5.000000e+05
# mean    1.330096e+06  9.376163e+05  3.924800e+05
# std     1.468090e+06  1.148684e+06  3.787517e+05
# min     9.330000e+00  6.920000e+00  2.410000e+00
# 25%     2.783059e+05  1.620597e+05  9.538506e+04
# 50%     7.862426e+05  4.677120e+05  2.817492e+05
# ...

# %%
d = pd.DataFrame(data)

# %%
d
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
s.array(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-8fede1c92922> in <module>
# ----> 1 s.array(data)
#
# TypeError: 'PandasArray' object is not callable

# %%
data
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
s = data(['Order Date'])
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-ad613b887f8e> in <module>
# ----> 1 s = data(['Order Date'])
#       2 s
#
# TypeError: 'DataFrame' object is not callable

# %%
data.head()
# Out:
#                          Region           Country  Item Type Sales Channel  \
# 0            Sub-Saharan Africa      South Africa     Fruits       Offline
# 1  Middle East and North Africa           Morocco    Clothes        Online
# 2         Australia and Oceania  Papua New Guinea       Meat       Offline
# 3            Sub-Saharan Africa          Djibouti    Clothes       Offline
# 4                        Europe          Slovakia  Beverages       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M   7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M   9/14/2013  667593514  10/19/2013        4611      109.28
# 2              M   5/15/2015  940995585    6/4/2015         360      421.89
# 3              H   5/17/2017  880811536    7/2/2017         562      109.28
# 4              L  10/26/2016  174590194   12/4/2016        3973       47.45
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
data.shape
# Out:
# (500000, 14)

# %%
data.ndim
# Out:
# 2

# %%
data.tail(20)
# Out:
#                                    Region               Country  \
# 499980                             Europe                Latvia
# 499981  Central America and the Caribbean                Panama
# 499982                 Sub-Saharan Africa     Equatorial Guinea
# 499983              Australia and Oceania                Tuvalu
# 499984                               Asia            Kyrgyzstan
# 499985                             Europe           Switzerland
# 499986                             Europe               Belarus
# 499987       Middle East and North Africa                 Syria
# 499988  Central America and the Caribbean             Guatemala
# 499989                             Europe              Slovenia
# 499990                             Europe              Moldova
# 499991                 Sub-Saharan Africa            Mauritania
# 499992                             Europe                Monaco
# 499993              Australia and Oceania                Tuvalu
# ...

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
data['Country'].describe()
# Out:
# count         500000
# unique           185
# top       Cape Verde
# freq            2840
# Name: Country, dtype: object

# %%
data['Region'].describe()
# Out:
# count                 500000
# unique                     7
# top       Sub-Saharan Africa
# freq                  130422
# Name: Region, dtype: object

# %%
data['Item Type'].describe()
# Out:
# count            500000
# unique               12
# top       Personal Care
# freq              41789
# Name: Item Type, dtype: object

# %%
data['Order Priority'].describe()
# Out:
# count     500000
# unique         4
# top            L
# freq      125138
# Name: Order Priority, dtype: object

# %%
[data['Units Sold'].sum(),
 data['Unit Cost'].sum(),
 data['Unit Price'].sum()]
# Out:
# [2499568055, 93764282.17, 133018374.19]

# %%
[data['Total Revenue'].sum(),
 data['Total Cost'].sum(),
 data['Total Profit'].sum()]
# Out:
# [665048154990.8003, 468808172696.5799, 196239982294.22006]

# %%
[data['Total Profit'].min(),
data['Total Profit'].max()]
# Out:
# [2.41, 1738700.0]

# %%
[data['Total Cost'].min(),
data['Total Cost'].max()]
# Out:
# [6.92, 5249600.0]

# %%
[data['Total Revenue'].min(),
data['Total Revenue'].max()]
# Out:
# [9.33, 6682700.0]
